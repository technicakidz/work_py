# %%
# -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# 配列の生成
x = np.array([-100, 1000, -10])

# func.
g = np.tanh(x)

# %%
# 画面出力
plt.plot(g)
plt.show()

# %%
(32*32)/25
# Out:
# 40.96
